# %%
import pandas as pd
import numpy as np
from datetime import tzinfo, timedelta, datetime
import os
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import re
from tqdm import tqdm, trange, tqdm_notebook
from multiprocessing import pool
import seaborn as sns
from pivottablejs import pivot_ui
from konlpy.tag import Okt

# %% [markdown]
# #### 구매자 판매자 데이터 로드

# %%
df_bunp_all = pd.read_csv('../../mac/Bunjang_csv_data/bunp_seller_buyer_201701_201905.csv')
df_bunpay_transfer_all = pd.read_csv('../../mac/Bunjang_csv_data/bunpay_transfer_seller_buyer_201701_201905.csv')

# %% [markdown]
# #### 데이터 통합

# %%
df_bunp_all.head()
# Out:
#             updated_at  type  seller_uid  buyer_uid  total_price
# 0  2019-01-06 00:29:51  bunp        7290    8037251        37000
# 1  2019-05-18 18:37:46  bunp        8847    3673304         8000
# 2  2017-06-03 00:21:37  bunp        5479    3313173       800000
# 3  2018-11-27 18:15:18  bunp       13475      38784        19900
# 4  2017-07-01 17:23:10  bunp       19041    3934154        39000

# %%
df_bunpay_transfer_all.head()
# Out:
#             updated_at    type  seller_uid  buyer_uid  total_price
# 0  2018-04-17 17:09:43  bunpay     6553285    6216460       173550
# 1  2018-04-17 17:09:43  bunpay     6823120    6595915       248200
# 2  2018-04-17 17:09:43  bunpay      654290    1431716        49410
# 3  2018-04-17 17:09:43  bunpay     3004670     718680       150200
# 4  2018-04-17 17:09:43  bunpay     2685990    3332255       310000

# %%
df_transaction_all = pd.concat([df_bunp_all, df_bunpay_transfer_all], axis=0)

# %%
df_transaction_all.head()
# Out:
#             updated_at  type  seller_uid  buyer_uid  total_price
# 0  2019-01-06 00:29:51  bunp        7290    8037251        37000
# 1  2019-05-18 18:37:46  bunp        8847    3673304         8000
# 2  2017-06-03 00:21:37  bunp        5479    3313173       800000
# 3  2018-11-27 18:15:18  bunp       13475      38784        19900
# 4  2017-07-01 17:23:10  bunp       19041    3934154        39000

# %%
df_transaction_all.shape
# Out:
# (4158151, 5)

# %%
df_transaction_all.updated_at.max()
# Out:
# '2019-05-31 23:58:00'

# %%
df_transaction_all.updated_at.min()
# Out:
# '2017-01-01 00:04:02'

# %% [markdown]
# #### 사기 데이터 불러오기

# %%
df_fraud = pd.read_csv('../Bunjang_csv_data/fraud_report_data_2019_2016.csv')

# %%
df_fraud.head()
# Out:
#         신고일자       거래품목     거래금액     신고자uid  신고대상uid
# 0  2010.2.11     갤럭시 s8  100,000  5160590.0  5815049
# 1  2015.1.12  노트3 SK/LG   70,000   299974.0  4222952
# 2  2015.1.13       아이폰6  250,000  3040425.0  4245137
# 3  2015.1.15       게임계정   50,000  4244022.0  4109047
# 4  2015.1.16     갤럭시노트3  125,000  2479816.0  4248663

# %%
df_fraud.columns = ['reported_date', 'product_name', 'price', 'reporter_uid', 'fraud_uid']

# %%
df_fraud.dropna(inplace=True)

# %%
df_fraud.reset_index(inplace=True, drop=True)

# %%
df_fraud.head()
# Out:
#   reported_date product_name    price  reporter_uid  fraud_uid
# 0     2010.2.11       갤럭시 s8  100,000     5160590.0    5815049
# 1     2015.1.12    노트3 SK/LG   70,000      299974.0    4222952
# 2     2015.1.13         아이폰6  250,000     3040425.0    4245137
# 3     2015.1.15         게임계정   50,000     4244022.0    4109047
# 4     2015.1.16       갤럭시노트3  125,000     2479816.0    4248663

# %% [markdown]
# #### 사기 데이터 중에서 현재 차단중인 사용자만 분류

# %%
df_blocked = pd.read_csv('../Bunjang_csv_data/blocked_uid_list_20190702.csv')

# %%
df_blocked.head()
# Out:
#     uid
# 0     0
# 1     3
# 2     6
# 3  2709
# 4  3203

# %%
df_blocked.columns = ['fraud_uid']

# %%
df_fraud = pd.merge(df_fraud, df_blocked, on='fraud_uid', how='inner')

# %%
df_fraud.shape
# Out:
# (13763, 5)

# %% [markdown]
# #### 사기 데이터 전처리
# - 거래 데이터가 2017년 1월부터이므로 신고 접수일이 2017년 1월 이후인 것으로 분류

# %%
df_fraud = df_fraud.loc[df_fraud.reported_date >= '2017-01-01']

# %%
df_fraud.reset_index(inplace=True, drop=True)

# %%
df_fraud.shape
# Out:
# (9827, 5)

# %%
df_fraud.head()
# Out:
#   reported_date      product_name    price  reporter_uid  fraud_uid
# 0     2017.1.15            컴퓨터 본체  170,000     3651257.0    4582938
# 1      2017.1.5         캘빈클라인 청자켓   40,000     2519709.0    4788446
# 2     2017.4.25         롤 아이디 팝니다   15,000     5523143.0    2153536
# 3     2017.8.27           박세웅 사인볼   23,000     5975291.0     247569
# 4     2017.1.15  아이폰 6플러스 골드 64기가  310,000     4016224.0     956841

# %% [markdown]
# #### 거래품목으로 카테고리 분류

# %%
okt=Okt()  

def tokenizer_okt_morphs(doc):
    return okt.morphs(doc)

def tokenizer_okt_noun(doc):
    return okt.nouns(doc)

def tokenizer_okt_pos(doc):
    return okt.pos(doc, norm=True, stem=True)

# %%
df_fraud['product_name_word'] = df_fraud['product_name'].apply(lambda x: tokenizer_okt_morphs(x))

# %%
df_fraud.head()
# Out:
#   reported_date      product_name    price  reporter_uid  fraud_uid  \
# 0     2017.1.15            컴퓨터 본체  170,000     3651257.0    4582938
# 1      2017.1.5         캘빈클라인 청자켓   40,000     2519709.0    4788446
# 2     2017.4.25         롤 아이디 팝니다   15,000     5523143.0    2153536
# 3     2017.8.27           박세웅 사인볼   23,000     5975291.0     247569
# 4     2017.1.15  아이폰 6플러스 골드 64기가  310,000     4016224.0     956841
#
#              product_name_word
# 0                    [컴퓨터, 본체]
# 1             [캘빈, 클라인, 청, 자켓]
# 2                [롤, 아이디, 팝니다]
# 3                 [박세웅, 사인, 볼]
# 4  [아이폰, 6, 플러스, 골드, 64, 기, 가]

# %%
df_fraud.loc[df_fraud.product_name_word.apply(lambda x: len(x) < 1)]
# Out:
#      reported_date product_name    price  reporter_uid  fraud_uid  \
# 3733     2017.8.12               820,000     4809587.0    5909359
#
#      product_name_word
# 3733                []

# %%
tokens = [ t for d in df_fraud['product_name_word'] for t in d]

# %%
print(len(tokens))
# Out:
# 31229

# %%
import nltk

# %%
text = nltk.Text(tokens, name='NMSC')

# %%
print(len(text.tokens))
# Out:
# 31229

# %%
print(len(set(text.tokens)))
# Out:
# 3485

# %%
print(text.vocab().most_common(90))
# Out:
# [('아이폰', 2540), ('6', 1132), ('s', 1110), ('7', 1070), ('에어팟', 904), ('갤럭시', 819), ('8', 620), ('플러스', 410), ('가', 354), ('노트', 346), ('기', 327), ('64', 292), ('5', 284), ('+', 284), ('지갑', 267), ('골드', 241), ('구찌', 231), ('상품권', 226), ('반', 209), ('즈', 198), ('2', 193), ('블랙', 193), ('롱패딩', 188), ('3', 184), ('무스', 184), ('너클', 181), ('로', 180), ('128', 173), ('4', 170), ('se', 158), ('g', 143), ('나이키', 141), ('문화', 138), ('S', 135), ('맨', 131), ('투맨', 130), ('티', 130), ('닌텐도', 115), ('패딩', 114), ('스네이크', 114), ('후드', 111), ('매트', 111), ('엣지', 110), ('노트북', 109), ('버니', 107), ('스웨터', 106), ('아이패드', 106), ('백', 104), ('x', 103), (',', 97), ('스', 94), ('아이', 93), ('레드', 90), ('삼성', 88), ('이', 84), ('스톤아일랜드', 82), ('스위치', 82), ('구', 76), ('팔', 74), ('프로', 73), ('집업', 72), ('루이비통', 72), ('데상트', 71), ('그레이', 71), ('gb', 68), ('티켓', 67), ('9', 67), ('G', 67), ('실버', 66), ('계정', 66), ('k', 65), ('디스커버리', 65), ('스페이스', 65), ('시계', 63), ('아디다스', 62), ('1', 62), ('장', 62), ('다이슨', 61), ('가방', 60), ('버즈', 60), ('세트', 58), ('지', 56), ('a', 56), ('lg', 55), ('브라운', 55), ('팩', 54), ('애플', 54), ('컴퓨터', 53), ('클러치', 53), ('골든', 52)]

# %%
print(text.vocab().most_common()[:-20:-1])
# Out:
# [('마리오카트', 1), ('46', 1), ('풀셋트', 1), ('슬링', 1), ('스위', 1), ('5억', 1), ('bp', 1), ('페라리', 1), ('노초', 1), ('와플', 1), ('LDV', 1), ('사카이', 1), ('SA', 1), ('널지오', 1), ('셔', 1), ('방한', 1), ('널', 1), ('플펜슬', 1), ('하의', 1)]

# %%
word_dict = {
    '디지털/가전': ['아이폰','s','6', '갤럭시','7', '에어팟', '노트','5', '8', '64', '+', '2', '3',
               '4', 'gb', '플러스', '스페이스', 'lg', '9', 'x', 'G', '노트북', 'S', '아이패드', 
               '청소기', '에어팟', '노트', '플러스', '엣지', '삼성', '컴퓨터', '핸드폰', '다이슨',
               '애플', '갤럭시탭', '모니터', '이어폰', '휴대폰', '스마트폰', '겔럭시', '기어', '베가',
               '배터리', '패드', '미러리스', '아이팟', '맥북', '캐논', '소니', '카메라', '케이스',
               '에어컨', '공기청정기', '그램', '블루투스', '아이팟', '아이', '그래픽카드', '탭', '본체',
               '루나', '프로', '폰', '로지텍', '밥솥', '맥', '마우스', '제습기', '블랙베리',
               '인치', '청축', '태블릿', '램', '외장하드', '무선', '고데기', 'gtx', '1060', 'LG'
              ],
    '패션/잡화' : ['지갑', '가방', '신발', '클러치', '모자', '시계', '구두', '백', '목걸이', '팔찌',
               '반지', '슬리퍼', '축구화', '벨트', '금반지', '루이비통', '구찌', '샤넬', '지샥',
               '파우치', '가발', '선글라스', '머니클립', '발렌시아', '귀걸이', '안경'
              ],
    '패션/잡화_운동화/캐쥬얼화' : ['운동화','스니커즈', '조던', '맥스', '힙색', '부스트', '나이키',
                       '아디다스', '골든', '슈퍼스타'],
    '도서/티켓/애완/취미': ['상품권', '문화', '티켓', '콘서트', '데이터', '규어', '기프트카드', '카드',
                   '인형', '이용권', '책', '치킨', '문상', '스타벅스', '기프티콘'],
    '여성/남성의류': ['롱패딩', '옷', '패딩', '자켓', '후드', '집업', '스웨터', '원피스',
                '바지', '가디건', '맨투맨', '투맨', '티', '코트', '니트', '트레이닝', '바람막이',
                '트레이닝복' ,'셔츠', '의류', '폴라', '점퍼', '무스', '너클', '스톤아일랜드',
                '스커트', '져지', '팬츠', '레깅스', '노스페이스', '밀포드', '히말라야', '디스커버리',
                '캐나다구스', '파타고니아', '스퀘어', '치마', '수트', '티셔츠', '청바지', '스파이더'
               ],
    '문구/가구/식품' : ['인스', '분유'],
    '스포츠/레저': ['자전거', '픽시', '야구', '라켓'],
    '스타굿즈': ['방탄소년단', '엑소', '인피니트', '포카', '트와이스', '방탄', '포토', '앨범', '싸인', 
            '포스터', '벨벳', '에이핑크', '응원봉'],
    '디지털/가전_게임/타이틀' : ['닌텐도', '오버', '피파', '계정', '아이디', '게임', '롤', '플레이스테이션',
                      '플스', '몬스터', '엑스박스', '모두의마블'],
    '뷰티/미용' : ['입생로랑', '팩', '마스크', '틴트', '향수', '쿠션', '크림', '밤', '립스틱', '에뛰드',
              '화장품', '파운데이션'],
    '차량/오토바이' : ['오토바이'],
    '유아동/출산': ['소독기']
}

# %%
list_product_name = list(df_fraud.product_name)
list_category = []
for i in range(len(list_product_name)):    
    flag_word = False
    flag_key = False
#     print(i, list_product_name[i])
    for key in word_dict.keys():
        if flag_key == False:
            for word in word_dict[key]:
#                 print('key: {key} / word: {word}'.format(key=key, word=word))
                if word in list_product_name[i]:
                    list_category.append(key)
                    flag_key = True
#                     print('find_key')
                    break
#     print('end of search')
    flag_word = True
    if (flag_word == True) & (flag_key == False):
        list_category.append('no_category')
#         print('No key')

# %%
df_fraud.shape
# Out:
# (9827, 6)

# %%
df_fraud['category'] = pd.Series(list_category)

# %%
df_fraud_no_category = df_fraud.loc[df_fraud.category == 'no_category']

# %%
df_fraud_no_category.shape
# Out:
# (612, 7)

# %%
df_fraud_no_category.head(100)
# Out:
#      reported_date    product_name      price  reporter_uid  fraud_uid  \
# 3        2017.8.27         박세웅 사인볼     23,000     5975291.0     247569
# 10        2017.4.5        닐바렛 네오프렌     51,500     5174537.0     405859
# 11       2017.2.13           향스프레이     18,000     3518962.0     181589
# 18        2017.1.4             뿌링클     23,000     4517992.0    4355616
# 25        2017.1.4             라이터     40,000     5168350.0    4966224
# 27       2018.2.17          잔트렉스블루     18,000     5989592.0    4881626
# 29       2018.4.16       까르띠에정품러브링    160,000     5155810.0    1173166
# 38       2017.3.15       대한간호협회문제집      6,000     3307278.0    4653718
# 39        2017.7.5             자이글     53,000     2757941.0    1645813
# 40       2017.4.11             랩핑지     10,000     4148953.0    2487386
# 60       2017.1.10         반스체크어센틱     40,000     4935745.0    4758658
# 75       2017.1.11          초커블라우스     10,000     3078201.0     416029
# 81       2017.1.11          검정 베레모      8,000     2772582.0    4816710
# 82       2017.1.12          검정 베레모      8,000     4525919.0    4816710
# 86       2017.1.11              교복     55,000      889357.0    4910625
# 110      2017.1.12          에어포스 1     60,000     2424170.0    5216065
# 118      2017.1.13              사과     20,000     1802300.0    3274572
# 154      2017.1.14          나인봇 미니    190,000     4636230.0    5218786
# 155      2017.1.15            홀리스터      8,000     4447570.0    2461936
# 194      2017.1.17        양털 떡볶이코드     12,000     1909478.0    1026638
# 197      2017.1.17  꿀큥이 일반입금 양도합니다     25,000     4868577.0    4249104
# 223       2017.3.1           엠프 급쳐     17,000     4864796.0    4044052
# 237      2017.1.19      공진향 히스토리 후    270,000     1172990.0    4136108
# 317      2017.1.24         오니츠카타이거     60,000     1260249.0     506360
# 321      2017.1.24            체크남방     19,000     2485738.0    1599624
# 324      2017.1.24         디올 립글로우     20,000     3547296.0    3502027
# 328      2017.1.24    도스노벤타 휴스턴 완차  1,000,000     2280522.0    4673451
# 329      2017.1.24             그룹셋    300,000     4838908.0    4673451
# 336      2017.1.25          보테가베네타    230,000     2428854.0     306171
# 338      2017.1.31       필이너프 ma-1    250,000     2379720.0    2108330
# ...            ...             ...        ...           ...        ...
# 861      2017.11.1        루카스 엔진오일    115,000     4217155.0    1377389
# 869      2017.12.2           스피드러너    150,000     5097580.0    5536049
# 890     2017.11.11            치간칫솔     20,000     4900933.0    6076982
# 896     2017.11.15         꿈비 범퍼침대    100,000     1389210.0    5935806
# 898      2017.11.6         린나이가스렌지     60,000     1247263.0    5935806
# 911     2017.11.13         데상트 아우디     70,000     3689682.0    6253373
# 916     2017.11.18            곤약젤리    129,000     4595447.0    1485577
# 917     2017.11.19            곤약젤리    145,000     1664293.0    1485577
# 926     2017.11.14         스톤 아일랜드     90,000     3803151.0    6263044
# 939     2017.11.16            톰브라운    700,000      202521.0    2224929
# 952     2017.11.17    마빅 저지 사이클 고글     87,000     6079870.0    3865596
# 961     2017.11.17          평창구스다운    150,000     6301184.0    6155453
# 981     2017.11.19         마인드 브릿지     11,000     4469600.0    2216519
# 1004    2017.11.20        미샤 이틸프리즘      5,000     4704258.0    5674615
# 1012    2017.11.21        마샬 앰프 액톤    150,000     6062424.0    6303611
# 1022    2017.11.22             족욕기     25,000     6042040.0    4854031
# 1040    2017.11.23         칼슈미트주서기     30,000      384555.0    6325917
# 1041    2017.11.27       지탈렌에어프라이어     20,000     3121098.0    6325917
# 1064    2017.11.25       비투비 공식 굿즈     12,500     1348829.0    3889631
# 1074    2017.11.27          바버 비데일    230,000     6062031.0    4643224
# 1077    2017.11.25           미니냉장고     25,000     2200752.0    5048961
# 1084    2017.11.26   잠자는 포켓몬 동물들가챠      3,500     2179254.0    3058092
# 1093    2017.11.27             로즈몽    114,000      202096.0     846603
# 1097    2017.11.27     오로라 공주의 사생활      1,000     2877978.0    4786653
# 1111    2017.11.29       질레트 면도날 칠     15,000     4123530.0    4241823
# 1137    2017.11.30         까르띠에 파샤    200,000     4646977.0    3557031
# 1141    2017.11.30            k1a총     20,000     6019813.0    5482684
# 1147     2017.11.4    요하이 박지훈 전신브마      9,000     6086920.0    5782019
# 1187     2017.11.9         리나슈슈 밍키    110,000     1721694.0    5495341
# 1195     2017.12.1       폴스부띠끄블랙라지     50,000     2712093.0    5729405
#
#                  product_name_word     category
# 3                     [박세웅, 사인, 볼]  no_category
# 10                   [닐, 바렛, 네오프렌]  no_category
# 11                       [향, 스프레이]  no_category
# 18                         [뿌, 링클]  no_category
# 25                           [라이터]  no_category
# 27                    [잔트, 렉스, 블루]  no_category
# 29           [까, 르띠, 에, 정품, 러브, 링]  no_category
# 38         [대, 한, 간호, 협회, 문, 제, 집]  no_category
# 39                         [자, 이글]  no_category
# 40                         [랩핑, 지]  no_category
# 60               [반스, 체크, 어, 센, 틱]  no_category
# 75                    [초, 커, 블라우스]  no_category
# 81                       [검정, 베레모]  no_category
# 82                       [검정, 베레모]  no_category
# 86                            [교복]  no_category
# 110                      [에어포스, 1]  no_category
# 118                           [사과]  no_category
# 154                    [나인, 봇, 미니]  no_category
# 155                       [홀리스, 터]  no_category
# 194                  [양털, 떡볶이, 코드]  no_category
# 197   [꿀큥, 이, 일반, 입금, 양, 도합, 니, 다]  no_category
# 223                     [엠프, 급, 쳐]  no_category
# 237               [공진, 향, 히스토리, 후]  no_category
# 317                  [오니, 츠카, 타이거]  no_category
# 321                       [체크, 남방]  no_category
# 324                   [디올, 립글, 로우]  no_category
# 328         [도스, 노, 벤, 타, 휴스턴, 완차]  no_category
# 329                        [그룹, 셋]  no_category
# 336                       [보테가베네타]  no_category
# 338           [필, 이, 너프, ma, -, 1]  no_category
# ...                            ...          ...
# 861                    [루카스, 엔진오일]  no_category
# 869                      [스피드, 러너]  no_category
# 890                     [치, 간, 칫솔]  no_category
# 896                   [꿈비, 범퍼, 침대]  no_category
# 898                  [린, 나이, 가스렌지]  no_category
# 911                     [데상트, 아우디]  no_category
# 916                       [곤약, 젤리]  no_category
# 917                       [곤약, 젤리]  no_category
# 926                     [스톤, 아일랜드]  no_category
# 939                       [톰, 브라운]  no_category
# 952              [마빅, 저지, 사이클, 고글]  no_category
# 961                 [평창, 구, 스, 다운]  no_category
# 981                     [마인드, 브릿지]  no_category
# 1004               [미샤, 이, 틸, 프리즘]  no_category
# 1012                  [마샬, 앰프, 액톤]  no_category
# 1022                       [족욕, 기]  no_category
# 1040               [칼, 슈미트, 주, 서기]  no_category
# 1041             [지, 탈렌, 에어, 프라이어]  no_category
# 1064               [비투비, 공식, 굿, 즈]  no_category
# 1074                   [바버, 비데, 일]  no_category
# 1077                     [미니, 냉장고]  no_category
# 1084       [잠자는, 포켓몬, 동물, 들, 가, 챠]  no_category
# 1093                         [로즈몽]  no_category
# 1097             [오로라, 공주, 의, 사생활]  no_category
# 1111                 [질레트, 면도날, 칠]  no_category
# 1137                  [까르띠, 에, 파샤]  no_category
# 1141                  [k, 1, a, 총]  no_category
# 1147          [요, 하이, 박지훈, 전신, 브마]  no_category
# 1187                  [리나, 슈슈, 밍키]  no_category
# 1195             [폴스부띠, 끄, 블랙, 라지]  no_category
#
# [100 rows x 7 columns]

# %% [markdown]
# #### 카테고리 분류 안된 단어 토큰 재확인

# %%
tokens_no_category = [ t for d in df_fraud_no_category['product_name_word'] for t in d]

# %%
text_no_category = nltk.Text(tokens_no_category, name='NMSC')

# %%
print(text_no_category.vocab().most_common(100))
# Out:
# [('즈', 19), ('이', 16), ('팔', 16), ('너', 15), ('보드', 14), ('굿', 13), ('반', 13), ('세트', 12), ('1', 10), ('의', 10), (',', 10), ('브라운', 9), ('원', 8), ('후', 7), ('스', 7), ('구', 7), ('아', 7), ('패치', 7), ('키', 7), ('네', 7), ('전', 7), ('동', 7), ('로', 7), ('워', 6), ('킥', 6), ('유니폼', 6), ('데상트', 6), ('틴', 6), ('블루', 5), ('제', 5), ('래', 5), ('라', 5), ('톰', 5), ('슬로건', 5), ('화이트', 5), ('드릴', 5), ('권', 5), ('세븐', 5), ('디스', 5), ('박스', 5), ('리스', 5), ('핑크', 5), ('에', 4), ('대', 4), ('지', 4), ('체크', 4), ('미니', 4), ('이름', 4), ('은', 4), ('플', 4), ('시', 4), ('탑', 4), ('곤약', 4), ('젤리', 4), ('에어', 4), ('일', 4), ('전자담배', 4), ('롱', 4), ('(', 4), (')', 4), ('오', 4), ('랜덤', 4), ('kt', 4), ('필립스', 4), ('허', 4), ('벌', 4), ('라이프', 4), ('봉', 4), ('업', 4), ('베이', 4), ('디테', 4), ('스타', 4), ('크롬', 4), ('글', 4), ('데스크탑', 4), ('오프', 4), ('카이', 4), ('링', 3), ('집', 3), ('반스', 3), ('검정', 3), ('양털', 3), ('디올', 3), ('와인', 3), ('스마트', 3), ('김치냉장고', 3), ('크', 3), ('트', 3), ('스톤', 3), ('와', 3), ('펜', 3), ('러너', 3), ('다운', 3), ('칼', 3), ('까르띠', 3), ('하이', 3), ('블랙', 3), ('화', 3), ('셋트', 3), ('정수기', 3)]

# %%
df_fraud.groupby('category').count()
# Out:
#                 reported_date  product_name  price  reporter_uid  fraud_uid  \
# category
# no_category               612           612    612           612        612
# 도서/티켓/애완/취미               381           381    381           381        381
# 디지털/가전                   6484          6484   6484          6484       6484
# 디지털/가전_게임/타이틀             194           194    194           194        194
# 문구/가구/식품                   16            16     16            16         16
# 뷰티/미용                      46            46     46            46         46
# 스타굿즈                       72            72     72            72         72
# 스포츠/레저                     14            14     14            14         14
# 여성/남성의류                  1033          1033   1033          1033       1033
# 유아동/출산                      1             1      1             1          1
# 차량/오토바이                     5             5      5             5          5
# 패션/잡화                     745           745    745           745        745
# 패션/잡화_운동화/캐쥬얼화            224           224    224           224        224
#
#                 product_name_word
# category
# no_category                   612
# 도서/티켓/애완/취미                   381
# 디지털/가전                       6484
# 디지털/가전_게임/타이틀                 194
# 문구/가구/식품                       16
# 뷰티/미용                          46
# 스타굿즈                           72
# 스포츠/레저                         14
# 여성/남성의류                      1033
# 유아동/출산                          1
# 차량/오토바이                         5
# 패션/잡화                         745
# 패션/잡화_운동화/캐쥬얼화                224

# %% [markdown]
# #### 사기발생 전 거래건수 확인

# %%
df_fraud.head()
# Out:
#   reported_date      product_name    price  reporter_uid  fraud_uid  \
# 0     2017.1.15            컴퓨터 본체  170,000     3651257.0    4582938
# 1      2017.1.5         캘빈클라인 청자켓   40,000     2519709.0    4788446
# 2     2017.4.25         롤 아이디 팝니다   15,000     5523143.0    2153536
# 3     2017.8.27           박세웅 사인볼   23,000     5975291.0     247569
# 4     2017.1.15  아이폰 6플러스 골드 64기가  310,000     4016224.0     956841
#
#              product_name_word     category
# 0                    [컴퓨터, 본체]       디지털/가전
# 1             [캘빈, 클라인, 청, 자켓]      여성/남성의류
# 2                [롤, 아이디, 팝니다]       디지털/가전
# 3                 [박세웅, 사인, 볼]  no_category
# 4  [아이폰, 6, 플러스, 골드, 64, 기, 가]       디지털/가전

# %%
df_transaction_all.head()
# Out:
#             updated_at  type  seller_uid  buyer_uid  total_price
# 0  2019-01-06 00:29:51  bunp        7290    8037251        37000
# 1  2019-05-18 18:37:46  bunp        8847    3673304         8000
# 2  2017-06-03 00:21:37  bunp        5479    3313173       800000
# 3  2018-11-27 18:15:18  bunp       13475      38784        19900
# 4  2017-07-01 17:23:10  bunp       19041    3934154        39000

# %%
list_fraud_uid = list(df_fraud.fraud_uid)

# %% [markdown]
# #### 첫 신고일자 기준으로 신고데이터 정리

# %%
df_fraud.fraud_uid.nunique()
# Out:
# 7301

# %%
df_fraud.head()
# Out:
#   reported_date      product_name    price  reporter_uid  fraud_uid  \
# 0     2017.1.15            컴퓨터 본체  170,000     3651257.0    4582938
# 1      2017.1.5         캘빈클라인 청자켓   40,000     2519709.0    4788446
# 2     2017.4.25         롤 아이디 팝니다   15,000     5523143.0    2153536
# 3     2017.8.27           박세웅 사인볼   23,000     5975291.0     247569
# 4     2017.1.15  아이폰 6플러스 골드 64기가  310,000     4016224.0     956841
#
#              product_name_word     category
# 0                    [컴퓨터, 본체]       디지털/가전
# 1             [캘빈, 클라인, 청, 자켓]      여성/남성의류
# 2                [롤, 아이디, 팝니다]       디지털/가전
# 3                 [박세웅, 사인, 볼]  no_category
# 4  [아이폰, 6, 플러스, 골드, 64, 기, 가]       디지털/가전

# %%
df_fraud_first = df_fraud.sort_values('reported_date').groupby('fraud_uid').first()

# %%
df_fraud_first.reset_index(inplace=True)

# %%
df_fraud_first.shape
# Out:
# (7301, 7)

# %%
df_fraud_first.head()
# Out:
#    fraud_uid reported_date product_name    price  reporter_uid  \
# 0       5196     2019.1.16          에어팟  400,000     3925192.0
# 1      28276    2018.10.14      덕다운 롱패딩  128,000     3124346.0
# 2      30444    2017.10.18         톰브라운   18,000     2222536.0
# 3      34547     2017.7.10        이지부스트  360,000     3717304.0
# 4      38137     2017.2.20       나이키슬리퍼   23,000     1850234.0
#
#   product_name_word        category
# 0             [에어팟]          디지털/가전
# 1      [덕, 다운, 롱패딩]         여성/남성의류
# 2          [톰, 브라운]     no_category
# 3       [이, 지, 부스트]  패션/잡화_운동화/캐쥬얼화
# 4        [나이키, 슬리퍼]           패션/잡화

# %%
df_count_by_seller = pd.DataFrame(columns=['seller_uid', 'type', 'updated_at'])
for i in trange(df_fraud_first.shape[0]):
    df_data = df_transaction_all.loc[
        (df_transaction_all.seller_uid == df_fraud_first.fraud_uid[i]) &
        (df_transaction_all.updated_at < df_fraud_first.reported_date[i])
    ]
    if df_data.shape[0] > 0:
        df_count = df_data[['updated_at', 'seller_uid', 'type']].groupby(
            ['seller_uid', 'type']).count().reset_index()
        df_count_by_seller = pd.concat([df_count_by_seller, df_count])
# Out:
# 100%|██████████| 7301/7301 [47:32<00:00,  2.56it/s]

# %%
df_count_by_seller
# Out:
#    seller_uid      type updated_at
# 0       28276      bunp          3
# 0       30444      bunp          2
# 0       34547      bunp          1
# 0       38137      bunp          7
# 0       39104      bunp          2
# 1       39104    bunpay          1
# 0       87523      bunp         10
# 0      103050      bunp          2
# 0      125571      bunp          2
# 0      137757      bunp          7
# 0      152482      bunp         15
# 0      166670      bunp          4
# 0      169789      bunp         62
# 0      169968      bunp          6
# 0      171519      bunp          6
# 0      181589      bunp        108
# 0      213885      bunp          1
# 0      215876      bunp          1
# 0      216148      bunp         16
# 0      216576      bunp          1
# 0      247569      bunp          5
# 0      251254      bunp          2
# 0      259116      bunp          3
# 0      265228      bunp          7
# 0      271097      bunp          2
# 0      272823      bunp          1
# 0      276559      bunp          1
# 0      292217      bunp         18
# 0      297669      bunp          4
# 0      297674      bunp          8
# ..        ...       ...        ...
# 0     6271080      bunp          6
# 0     6272949      bunp          8
# 0     6273845      bunp          1
# 0     6380890  transfer          1
# 0     6500375  transfer          1
# 0     6626518    bunpay          1
# 0     6891488  transfer          2
# 0     6896400    bunpay          1
# 0     6988757    bunpay          1
# 0     7015904    bunpay         31
# 0     7055545    bunpay          3
# 0     7215571    bunpay          1
# 0     7463615    bunpay          1
# 0     7472898    bunpay          1
# 0     7499983  transfer          1
# 0     7517653    bunpay          1
# 1     7517653  transfer          1
# 0     7672456  transfer          1
# 0     7732958  transfer          2
# 0     7739411  transfer          1
# 0     7750242    bunpay          1
# 0     7841242    bunpay         56
# 1     7841242  transfer         13
# 0     7844973  transfer          1
# 0     7989664  transfer          1
# 0     8142638    bunpay          1
# 0     8210018    bunpay          6
# 0     8311958  transfer          1
# 0     8325446    bunpay          7
# 1     8325446  transfer          3
#
# [2290 rows x 3 columns]

# %%
df_count_by_seller_pivot = df_count_by_seller.pivot('seller_uid', 'type')

# %%
df_count_by_seller_pivot.fillna(0, inplace=True)

# %%
df_count_by_seller_table = pd.DataFrame(df_count_by_seller_pivot.to_records())

# %%
df_count_by_seller_table.columns = ['fraud_uid', 'bunp', 'bunpay', 'transfer']

# %%
df_fraud_first.head()
# Out:
#    fraud_uid reported_date product_name    price  reporter_uid  \
# 0       5196     2019.1.16          에어팟  400,000     3925192.0
# 1      28276    2018.10.14      덕다운 롱패딩  128,000     3124346.0
# 2      30444    2017.10.18         톰브라운   18,000     2222536.0
# 3      34547     2017.7.10        이지부스트  360,000     3717304.0
# 4      38137     2017.2.20       나이키슬리퍼   23,000     1850234.0
#
#   product_name_word        category
# 0             [에어팟]          디지털/가전
# 1      [덕, 다운, 롱패딩]         여성/남성의류
# 2          [톰, 브라운]     no_category
# 3       [이, 지, 부스트]  패션/잡화_운동화/캐쥬얼화
# 4        [나이키, 슬리퍼]           패션/잡화

# %%
df_fraud_first.shape
# Out:
# (7301, 7)

# %% [markdown]
# #### 사기 데이터와 사기 발생 이전 거래 데이터 합치기

# %%
df_fraud_w_transaction = pd.merge(df_fraud_first, df_count_by_seller_table, on='fraud_uid', how = 'outer')

# %%
df_fraud_w_transaction.fillna(0, inplace=True)

# %%
df_fraud_w_transaction.head()
# Out:
#    fraud_uid reported_date product_name    price  reporter_uid  \
# 0       5196     2019.1.16          에어팟  400,000     3925192.0
# 1      28276    2018.10.14      덕다운 롱패딩  128,000     3124346.0
# 2      30444    2017.10.18         톰브라운   18,000     2222536.0
# 3      34547     2017.7.10        이지부스트  360,000     3717304.0
# 4      38137     2017.2.20       나이키슬리퍼   23,000     1850234.0
#
#   product_name_word        category  bunp  bunpay  transfer
# 0             [에어팟]          디지털/가전   0.0     0.0       0.0
# 1      [덕, 다운, 롱패딩]         여성/남성의류   3.0     0.0       0.0
# 2          [톰, 브라운]     no_category   2.0     0.0       0.0
# 3       [이, 지, 부스트]  패션/잡화_운동화/캐쥬얼화   1.0     0.0       0.0
# 4        [나이키, 슬리퍼]           패션/잡화   7.0     0.0       0.0

# %%
df_fraud_w_transaction.drop(columns=['product_name_word'], inplace=True)

# %%
df_fraud_w_transaction.shape
# Out:
# (7301, 9)

# %%
df_fraud_w_transaction.to_csv('../Downloads/fraud_list_uid.csv')

# %% [markdown]
# #### 전문상점 데이터 합치기

# %%
df_fraud_biz = pd.read_csv('../Bunjang_csv_data/biz_license.csv')

# %%
df_fraud_biz.head()
# Out:
#      uid  bizlicense
# 0   5196           0
# 1  28276           1
# 2  30444           0
# 3  34547           0
# 4  38137           0

# %%
df_fraud_biz.columns
# Out:
# Index(['uid', 'bizlicense'], dtype='object')

# %%
df_fraud_biz.columns = ['fraud_uid', 'is_bizlicense']

# %%
df_fraud_w_transaction_w_biz = pd.merge(df_fraud_w_transaction, df_fraud_biz, on='fraud_uid', how='outer')

# %%
df_fraud_w_transaction_w_biz.loc[df_fraud_w_transaction_w_biz.is_bizlicense.isna()]
# Out:
# Empty DataFrame
# Columns: [fraud_uid, reported_date, product_name, price, reporter_uid, category, bunp, bunpay, transfer, is_bizlicense]
# Index: []

# %%
df_fraud_w_transaction_w_biz.is_bizlicense.fillna('no_data', inplace=True)

# %%
df_fraud_w_transaction_w_biz
# Out:
#       fraud_uid reported_date            product_name    price  reporter_uid  \
# 0          5196     2019.1.16                     에어팟  400,000     3925192.0
# 1         28276    2018.10.14                 덕다운 롱패딩  128,000     3124346.0
# 2         30444    2017.10.18                    톰브라운   18,000     2222536.0
# 3         34547     2017.7.10                   이지부스트  360,000     3717304.0
# 4         38137     2017.2.20                  나이키슬리퍼   23,000     1850234.0
# 5         39104      2019.1.2               스피드러너 40c  500,000     6549814.0
# 6         55453     2017.1.17  기가 유무선 위보 공유기 뿔4개 듀얼코어   20,000     4335356.0
# 7         55883     2018.1.28                    구찌벨트  150,000     5255156.0
# 8         73040     2018.12.8                     에어팟  322,000     3092870.0
# 9         81559    2018.12.13                 커버낫 롱패딩  180,000     1567089.0
# 10        87523    2017.12.25                    남자시계  850,000     6014107.0
# 11        92504     2018.5.10                 갤럭시 6엣지   50,000     2713438.0
# 12        95740     2017.8.26                 펄스2 스피커  130,000     5321704.0
# 13       103050      2017.8.1              발렌티노 여성 지갑  230,000      236632.0
# 14       104940     2017.5.28                 jbl 펄스2  150,000     5670752.0
# 15       105403      2018.3.5                   아이폰6+  125,000     4858295.0
# 16       123475     2017.11.3               데상트 아우디패딩  230,000      903100.0
# 17       125571     2017.2.18                게이밍정품헤드셋   40,000      708074.0
# 18       137757     2018.2.26               마르셀로 불론 티   53,000     2557913.0
# 19       138563     2018.4.26                  에이서노트북  125,000     6481941.0
# 20       142414     2019.2.17              무스너클 버니스웨터  200,000     3429429.0
# 21       145337     2018.3.25                     상품권  560,000      463886.0
# 22       152482    2017.12.13                   인화스티커    3,500     3248234.0
# 23       153805     2018.1.12               크롬하츠 포에버링  110,000     5926534.0
# 24       162986    2018.12.16                    아이폰7  250,000     4573264.0
# 25       166670    2018.11.16                     에어팟  230,000     4884528.0
# 26       169789    2018.11.13           샤이니 종현 콘서트 후드  238,000     6283106.0
# 27       169968    2017.10.10           삼성로봇청소기, 쿠첸밥솥  330,000     4795923.0
# 28       171519     2018.2.23          발렌시아가 스피드러너1:1  143,000     5186490.0
# 29       180487     2017.1.21            포켓포토 인화지 5박스   43,000     3860982.0
# ...         ...           ...                     ...      ...           ...
# 7271    8970879      2019.5.6                     에어팟   125000     8356191.0
# 7272    8971466      2019.5.5             미개봉 에어팟 1세대   130000      384957.0
# 7273    8972534      2019.5.5              아이폰 6s 플러스   120000     1939976.0
# 7274    8974369      2019.5.6                     에어팟   140000     8883520.0
# 7275    8991219     2019.5.20                     에어팟   100000     2824917.0
# 7276    8998235     2019.5.14                  갤럭시 버즈   100000     4988107.0
# 7277    8999734      2019.5.9                     에어팟   120000      392982.0
# 7278    9000983      2019.5.9                     에어팟   150500      152702.0
# 7279    9008047     2019.5.11                    루이비통   352500     2712906.0
# 7280    9009015     2019.5.11                 아이폰8플러스   340000     2993764.0
# 7281    9009552     2019.5.11             에어팟 이어폰 1세대   150000      972200.0
# 7282    9010668     2019.5.11                 아이폰 7레드   190000     5947641.0
# 7283    9011625     2019.5.11                     에어팟   130000      451971.0
# 7284    9011702     2019.5.11                황금올리브 치킨    13000     7703691.0
# 7285    9012537     2019.5.12          에어팟 2세대 미개봉 유선   150000     7418709.0
# 7286    9013149     2019.5.11         구찌 스네이크 반지갑 풀박스   100000     7601171.0
# 7287    9014261     2019.5.14                 에어팟 1세대   130000     2770254.0
# 7288    9015612     2019.5.11                     에어팟   120000     6454513.0
# 7289    9016315     2019.5.13                     에어팟   250000      552278.0
# 7290    9018044     2019.5.12                  아이폰 se    80000     6125410.0
# 7291    9020277     2019.5.15           아이폰8플러스 256G/   490000     7344646.0
# 7292    9020442     2019.5.13                     에어팟   130000     5554525.0
# 7293    9027230     2019.5.14                     에어팟   120000     4174395.0
# 7294    9033863     2019.5.15                     에어팟   100000     6953392.0
# 7295    9043052     2019.5.20                  프라다 가방   480000     6282231.0
# 7296    9045033     2019.5.19                  에어팟2세대   150000     3490939.0
# 7297    9051770     2019.5.18                  갤럭시 버즈    90000     6053617.0
# 7298    9061008     2019.5.20                 아이폰7플러스    50000     4169151.0
# 7299    9078659     2019.5.22              에어팟1세대 미개봉   120000     2466614.0
# 7300    9082468     2019.5.23                   갤럭시버즈   100000     1561587.0
#
#             category  bunp  bunpay  transfer  is_bizlicense
# 0             디지털/가전   0.0     0.0       0.0              0
# 1            여성/남성의류   3.0     0.0       0.0              1
# 2        no_category   2.0     0.0       0.0              0
# 3     패션/잡화_운동화/캐쥬얼화   1.0     0.0       0.0              0
# 4              패션/잡화   7.0     0.0       0.0              0
# 5             디지털/가전   2.0     1.0       0.0              0
# 6             디지털/가전   0.0     0.0       0.0              0
# 7              패션/잡화   0.0     0.0       0.0              0
# 8             디지털/가전   0.0     0.0       0.0              0
# 9            여성/남성의류   0.0     0.0       0.0              0
# 10             패션/잡화  10.0     0.0       0.0              0
# 11            디지털/가전   0.0     0.0       0.0              0
# 12            디지털/가전   0.0     0.0       0.0              0
# 13             패션/잡화   2.0     0.0       0.0              0
# 14            디지털/가전   0.0     0.0       0.0              0
# 15            디지털/가전   0.0     0.0       0.0              1
# 16           여성/남성의류   0.0     0.0       0.0              0
# 17       no_category   2.0     0.0       0.0              0
# 18           여성/남성의류   7.0     0.0       0.0              0
# 19            디지털/가전   0.0     0.0       0.0              0
# 20           여성/남성의류   0.0     0.0       0.0              0
# 21       도서/티켓/애완/취미   0.0     0.0       0.0              1
# 22           여성/남성의류  15.0     0.0       0.0              0
# 23       no_category   0.0     0.0       0.0              0
# 24            디지털/가전   0.0     0.0       0.0              0
# 25            디지털/가전   4.0     0.0       0.0              0
# 26       도서/티켓/애완/취미  62.0     0.0       0.0              0
# 27            디지털/가전   6.0     0.0       0.0              0
# 28             패션/잡화   6.0     0.0       0.0              0
# 29            디지털/가전   0.0     0.0       0.0              0
# ...              ...   ...     ...       ...            ...
# 7271          디지털/가전   0.0     0.0       0.0              1
# 7272          디지털/가전   0.0     0.0       0.0              0
# 7273          디지털/가전   0.0     0.0       0.0              0
# 7274          디지털/가전   0.0     0.0       0.0              0
# 7275          디지털/가전   0.0     0.0       0.0              0
# 7276          디지털/가전   0.0     0.0       0.0              0
# 7277          디지털/가전   0.0     0.0       0.0              0
# 7278          디지털/가전   0.0     0.0       0.0              0
# 7279           패션/잡화   0.0     0.0       0.0              0
# 7280          디지털/가전   0.0     0.0       0.0              0
# 7281          디지털/가전   0.0     0.0       0.0              0
# 7282          디지털/가전   0.0     0.0       0.0              0
# 7283          디지털/가전   0.0     0.0       0.0              0
# 7284     도서/티켓/애완/취미   0.0     0.0       0.0              0
# 7285          디지털/가전   0.0     0.0       0.0              0
# 7286           패션/잡화   0.0     0.0       0.0              0
# 7287          디지털/가전   0.0     0.0       0.0              0
# 7288          디지털/가전   0.0     0.0       0.0              0
# 7289          디지털/가전   0.0     0.0       0.0              0
# 7290          디지털/가전   0.0     0.0       0.0              0
# 7291          디지털/가전   0.0     0.0       0.0              0
# 7292          디지털/가전   0.0     0.0       0.0              0
# 7293          디지털/가전   0.0     0.0       0.0              0
# 7294          디지털/가전   0.0     0.0       0.0              0
# 7295           패션/잡화   0.0     0.0       0.0              0
# 7296          디지털/가전   0.0     0.0       0.0              0
# 7297          디지털/가전   0.0     0.0       0.0              0
# 7298          디지털/가전   0.0     0.0       0.0              0
# 7299          디지털/가전   0.0     0.0       0.0              0
# 7300          디지털/가전   0.0     0.0       0.0              0
#
# [7301 rows x 10 columns]

# %%
df_fraud_w_transaction_w_biz.to_csv('../Downloads/fraud_transaction_w_biz.csv')
