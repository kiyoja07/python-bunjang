# %%
import pandas as pd
import json
from scipy import stats
import numpy as np

# %% [markdown]
# # 이벤트 기간에 참여한 유저

# %% [markdown]
# ### 가입 전체 유저

# %% [raw]
# # reward_pay_1.0_all_user.csv 산출 쿼리
#
# select date_format(u.join_date, '%Y-%m-%d') as join_date, u.id as uid
# from user u
# where date_format(u.join_date, '%Y-%m-%d') in ('2019-12-17', '2019-12-18', '2019-12-19')

# %%
read_path = '../csv/reward_pay_1.0_all_user.csv'
all_user = pd.read_csv(read_path)

all_user['uid'] = all_user['uid'].astype(str)

all_user
# Out:
#         join_date       uid
# 0      2019-12-17  10456692
# 1      2019-12-17  10456693
# 2      2019-12-17  10456694
# 3      2019-12-17  10456695
# 4      2019-12-17  10456696
# ...           ...       ...
# 16375  2019-12-19  10473808
# 16376  2019-12-19  10473809
# 16377  2019-12-19  10473810
# 16378  2019-12-19  10473811
# 16379  2019-12-19  10473812
#
# [16380 rows x 2 columns]

# %%
all_user.groupby(['join_date'], as_index=False).agg({'uid': 'count'})
# Out:
#     join_date   uid
# 0  2019-12-17  5785
# 1  2019-12-18  5483
# 2  2019-12-19  5112

# %% [markdown]
# ### 이벤트 대상 유저

# %%
read_path = '../csv/reward_pay_1.0_target_user.csv'
target_user = pd.read_csv(read_path)

target_user = target_user[(target_user['memo'] == 'group_1') | (target_user['memo'] == 'group_2') |
                         (target_user['memo'] == 'group_3') | (target_user['memo'] == 'group_4')] 

target_user = target_user.rename(columns={'target_uid': 'uid', 'memo': 'test_group'})

target_user = target_user[['event_date', 'uid', 'test_group']]

target_user['uid'] = target_user['uid'].astype(str)

target_user
# Out:
#       event_date       uid test_group
# 0     2019-12-18  10456697    group_2
# 1     2019-12-18  10456699    group_4
# 2     2019-12-18  10456707    group_4
# 3     2019-12-18  10456712    group_1
# 4     2019-12-18  10456713    group_2
# ...          ...       ...        ...
# 3943  2019-12-20  10473793    group_2
# 3944  2019-12-20  10473798    group_3
# 3945  2019-12-20  10473802    group_3
# 3946  2019-12-20  10473803    group_4
# 3947  2019-12-20  10473810    group_3
#
# [3940 rows x 3 columns]

# %% [markdown]
# ### 전체 가입 유저와 이벤트 대상 유저 merge

# %%
user = pd.merge(all_user, target_user, on='uid', how='left')

def group_reward(row):
    if row['test_group'] == 'group_1':
        return '1000'
    elif row['test_group'] == 'group_2':
        return '3000'
    elif row['test_group'] == 'group_3':
        return '5000'
    elif row['test_group'] == 'group_4':
        return '7000'
    else:
        return '0'

user['reward'] = user.apply(group_reward, axis=1)
    
user
# Out:
#         join_date       uid  event_date test_group reward
# 0      2019-12-17  10456692         NaN        NaN      0
# 1      2019-12-17  10456693         NaN        NaN      0
# 2      2019-12-17  10456694         NaN        NaN      0
# 3      2019-12-17  10456695         NaN        NaN      0
# 4      2019-12-17  10456696         NaN        NaN      0
# ...           ...       ...         ...        ...    ...
# 16375  2019-12-19  10473808         NaN        NaN      0
# 16376  2019-12-19  10473809         NaN        NaN      0
# 16377  2019-12-19  10473810  2019-12-20    group_3   5000
# 16378  2019-12-19  10473811         NaN        NaN      0
# 16379  2019-12-19  10473812         NaN        NaN      0
#
# [16380 rows x 5 columns]

# %% [markdown]
# # 이벤트 기간에 결제된 내역

# %% [markdown]
# ### 이벤트 결제 내역

# %% [raw]
# # reward_pay_1.0_all_pay.csv 산출 쿼리
#
# -- 번개 송금으로 결제
# select uid, paid_at, 'transfer' as pay_type, status
# from wire_transfer
# where date_format(paid_at, '%Y-%m-%d') between '2019-12-18' and '2020-01-03' and # 결제 기간
#     status in ('payment_received', 'verifying_delivery', 'transfer_completed')
#     # 가상계좌 입금 완료(운송장 번호 입력 대기), 송장번호 입력완료(배송확인중), 송금완료(운송장 검증 완료)
#
# union all
#
# -- 번개 페이로 결제
# select buyer_id, setl_done_date, 'pay' as pay_type, order_status_cd
# from order_mast
# where date_format(setl_done_date, '%Y-%m-%d') between '2019-12-18' and '2020-01-03' and # 결제 기간
#     order_status_cd in ('payment_received', 'ship_ready', 'in_transit', 'delivery_completed', 'purchase_confirm')
#     # 결제완료, 배송 준비 중, 배송 중, 배송 완료, 거래완료

# %%
read_path = '../csv/reward_pay_1.0_pay.csv'
pay = pd.read_csv(read_path)

pay['uid'] = pay['uid'].astype(str)

pay
# Out:
#             uid              paid_at  pay_type              status
# 0       4752408  2019-12-18 12:33:00  transfer  transfer_completed
# 1       6865289  2019-12-18 12:49:00  transfer  transfer_completed
# 2      10459160  2019-12-18 11:45:00  transfer  transfer_completed
# 3       5694740  2019-12-18 15:46:00  transfer  transfer_completed
# 4      10092496  2019-12-18 13:01:00  transfer  transfer_completed
# ...         ...                  ...       ...                 ...
# 26552   9658273  2020-01-03 23:09:50       pay          ship_ready
# 26553  10569707  2020-01-03 23:18:33       pay          ship_ready
# 26554   5623370  2020-01-03 23:41:29       pay          ship_ready
# 26555   3221775  2020-01-03 23:43:11       pay          ship_ready
# 26556   6276540  2020-01-03 23:48:57       pay          ship_ready
#
# [26557 rows x 4 columns]

# %% [markdown]
# ### 결제 내역과 이벤트 전체 유저 merge

# %%
pay_user = pd.merge(pay, user, on='uid')

pay_user
# Out:
#           uid              paid_at  pay_type              status   join_date  \
# 0    10459160  2019-12-18 11:45:00  transfer  transfer_completed  2019-12-17
# 1    10459160  2019-12-24 12:54:00  transfer  transfer_completed  2019-12-17
# 2    10459160  2019-12-26 17:30:01  transfer  transfer_completed  2019-12-17
# 3    10459160  2019-12-30 09:31:00  transfer  transfer_completed  2019-12-17
# 4    10459160  2019-12-30 09:31:00  transfer  transfer_completed  2019-12-17
# ..        ...                  ...       ...                 ...         ...
# 428  10471204  2019-12-30 23:48:20       pay    purchase_confirm  2019-12-19
# 429  10470940  2019-12-31 11:21:01       pay    purchase_confirm  2019-12-19
# 430  10464174  2019-12-18 10:48:31       pay          ship_ready  2019-12-18
# 431  10459096  2019-12-19 14:53:02       pay          ship_ready  2019-12-17
# 432  10461513  2019-12-20 12:19:20       pay          ship_ready  2019-12-17
#
#      event_date test_group reward
# 0           NaN        NaN      0
# 1           NaN        NaN      0
# 2           NaN        NaN      0
# 3           NaN        NaN      0
# 4           NaN        NaN      0
# ..          ...        ...    ...
# 428  2019-12-20    group_1   1000
# 429         NaN        NaN      0
# 430         NaN        NaN      0
# 431         NaN        NaN      0
# 432  2019-12-18    group_2   3000
#
# [433 rows x 8 columns]

# %%
pay_user_reward = pay_user.groupby(['reward', 'status'], as_index=False).agg({'paid_at': 'count', 'uid': pd.Series.nunique})

pay_user_reward
# Out:
#    reward              status  paid_at  uid
# 0       0  delivery_completed        6    5
# 1       0          in_transit        3    3
# 2       0    payment_received        3    3
# 3       0    purchase_confirm      138  101
# 4       0          ship_ready        2    2
# 5       0  transfer_completed      115   94
# 6    1000          in_transit        2    1
# 7    1000    payment_received        1    1
# 8    1000    purchase_confirm       10    8
# 9    1000  transfer_completed       30   25
# 10   1000  verifying_delivery        2    1
# 11   3000  delivery_completed        1    1
# 12   3000    payment_received        1    1
# 13   3000    purchase_confirm       19   14
# 14   3000          ship_ready        1    1
# 15   3000  transfer_completed       25   21
# 16   5000  delivery_completed        4    3
# 17   5000    purchase_confirm       14   14
# 18   5000  transfer_completed       25   24
# 19   7000  delivery_completed        2    2
# 20   7000          in_transit        2    2
# 21   7000    payment_received        1    1
# 22   7000    purchase_confirm       13    9
# 23   7000  transfer_completed       13   11

# %% [markdown]
# ### 이벤트 결제 실패 내역

# %% [raw]
# # reward_pay_1.0_all_pay_fail.csv 산출 쿼리
#
# -- 번개 송금으로 결제
# select uid, paid_at, 'transfer' as pay_type, status
# from wire_transfer
# where date_format(paid_at, '%Y-%m-%d') between '2019-12-18' and '2020-01-03' and # 결제 기간
#     status not in ('payment_received', 'verifying_delivery', 'transfer_completed')
#     # 가상계좌 입금 완료(운송장 번호 입력 대기), 송장번호 입력완료(배송확인중), 송금완료(운송장 검증 완료)
#
# union all
#
# -- 번개 페이로 결제
# select buyer_id, setl_done_date, 'pay' as pay_type, order_status_cd
# from order_mast
# where date_format(setl_done_date, '%Y-%m-%d') between '2019-12-18' and '2020-01-03' and # 결제 기간
#     order_status_cd not in ('payment_received', 'ship_ready', 'in_transit', 'delivery_completed', 'purchase_confirm')
#     # 결제완료, 배송 준비 중, 배송 중, 배송 완료, 거래완료

# %%
read_path = '../csv/reward_pay_1.0_pay_fail.csv'
pay_fail = pd.read_csv(read_path)

pay_fail['uid'] = pay_fail['uid'].astype(str)

pay_fail
# Out:
#            uid              paid_at  pay_type                           status
# 0      3457670  2019-12-18 01:33:00  transfer                         refunded
# 1      8688764  2019-12-18 00:40:00  transfer  waiting_bank_account_for_refund
# 2       102911  2019-12-18 00:14:00  transfer                         refunded
# 3     10455756  2019-12-18 00:19:00  transfer                         refunded
# 4     10150770  2019-12-18 00:41:00  transfer                         refunded
# ...        ...                  ...       ...                              ...
# 9550   6877063  2020-01-03 23:13:54       pay                         refunded
# 9551   6395957  2020-01-03 23:24:02       pay                         refunded
# 9552   8172576  2020-01-03 23:34:59       pay                         refunded
# 9553   6270760  2020-01-03 23:36:45       pay                         refunded
# 9554   8692266  2020-01-03 23:49:32       pay                         refunded
#
# [9555 rows x 4 columns]

# %%
pay_fail_user = pd.merge(pay_fail, user, on='uid')

pay_fail_user
# Out:
#           uid              paid_at  pay_type    status   join_date  \
# 0    10463121  2019-12-18 02:02:00  transfer  refunded  2019-12-18
# 1    10463545  2019-12-18 09:52:00  transfer  refunded  2019-12-18
# 2    10457964  2019-12-18 09:57:00  transfer  refunded  2019-12-17
# 3    10463007  2019-12-18 12:00:00  transfer  refunded  2019-12-18
# 4    10463916  2019-12-18 12:39:01  transfer  refunded  2019-12-18
# ..        ...                  ...       ...       ...         ...
# 161  10466858  2019-12-30 12:43:30       pay  refunded  2019-12-18
# 162  10462661  2020-01-02 14:21:00       pay  refunded  2019-12-17
# 163  10470679  2020-01-02 16:48:10       pay  refunded  2019-12-19
# 164  10458610  2020-01-03 14:30:48       pay  refunded  2019-12-17
# 165  10462464  2020-01-03 20:03:29       pay  refunded  2019-12-17
#
#      event_date test_group reward
# 0           NaN        NaN      0
# 1    2019-12-19    group_2   3000
# 2           NaN        NaN      0
# 3    2019-12-19    group_4   7000
# 4    2019-12-19    group_1   1000
# ..          ...        ...    ...
# 161         NaN        NaN      0
# 162         NaN        NaN      0
# 163         NaN        NaN      0
# 164         NaN        NaN      0
# 165         NaN        NaN      0
#
# [166 rows x 8 columns]

# %%
pay_fail_user_reward = pay_fail_user.groupby(['reward', 'status'], as_index=False).agg({'paid_at': 'count', 'uid': pd.Series.nunique})

pay_fail_user_reward
# Out:
#   reward                           status  paid_at  uid
# 0      0                         refunded       93   77
# 1      0  waiting_bank_account_for_refund        1    1
# 2      0               waiting_extra_info        1    1
# 3   1000                         refunded       17   14
# 4   3000                         refunded       22   15
# 5   3000  waiting_bank_account_for_refund        1    1
# 6   5000                         refunded       13   12
# 7   7000                         refunded       17   11
# 8   7000           return_before_shipping        1    1

# %% [markdown]
# # 이벤트 기간에 생성된 번프

# %% [raw]
# # reward_pay_1.0_bunp.csv 산출 쿼리
#
# select channel_id, seller_uid, buyer_uid, seller_pid, created_at
# from bunjang_promise
# where created_at >= '2019-12-18 00:00:00' AND created_at < '2020-01-04 00:00:00'

# %%
read_path = '../csv/reward_pay_1.0_bunp.csv'
bunp = pd.read_csv(read_path)

bunp['buyer_uid'] = bunp['buyer_uid'].astype(str)

bunp
# Out:
#         channel_id  seller_uid buyer_uid  seller_pid           created_at
# 0        174060916    10400414   9789553   113779233  2019-12-18 00:00:10
# 1        174049406     4019513   1967118   113720593  2019-12-18 00:01:38
# 2        174112346     7458727   1639610   105822185  2019-12-18 00:05:07
# 3        174111900     5523330   9786968   113802853  2019-12-18 00:05:16
# 4        169990639      665491   5565322   111984155  2019-12-18 00:05:28
# ...            ...         ...       ...         ...                  ...
# 262662   175828965     1215342   9954312   112420578  2019-12-31 11:46:00
# 262663   113029043     4191970   3157189   113966342  2020-01-01 07:06:11
# 262664   175774342     9245445   3020603   114384145  2019-12-30 09:46:49
# 262665   176082846     6944936  10116007   111536521  2020-01-01 09:24:56
# 262666   176013663      592482   4904518   114533620  2019-12-31 20:05:50
#
# [262667 rows x 5 columns]

# %%
bunp_user = pd.merge(bunp, user, left_on='buyer_uid', right_on='uid')

bunp_user
# Out:
#       channel_id  seller_uid buyer_uid  seller_pid           created_at  \
# 0      174115446    10461193  10456710   113788472  2019-12-18 00:17:17
# 1      174109595     5253974  10462604   113799351  2019-12-18 00:23:05
# 2      174128332     1617761  10463193   113769136  2019-12-18 02:36:22
# 3      174128332     1617761  10463193   113770439  2019-12-18 02:38:34
# 4      174128332     1617761  10463193   112244668  2019-12-18 02:40:46
# ...          ...         ...       ...         ...                  ...
# 1597   175942910     3736164  10460180   104508124  2019-12-31 02:12:38
# 1598   175840498     3150865  10457581    81372301  2019-12-31 13:52:38
# 1599   175944496      549877  10473019   114388772  2019-12-31 18:07:24
# 1600   176035290     5621881  10469663    98875726  2019-12-31 21:18:53
# 1601   174493223     9133736  10472828   111507533  2019-12-31 22:42:30
#
#        join_date       uid  event_date test_group reward
# 0     2019-12-17  10456710         NaN        NaN      0
# 1     2019-12-17  10462604         NaN        NaN      0
# 2     2019-12-18  10463193  2019-12-19    group_2   3000
# 3     2019-12-18  10463193  2019-12-19    group_2   3000
# 4     2019-12-18  10463193  2019-12-19    group_2   3000
# ...          ...       ...         ...        ...    ...
# 1597  2019-12-17  10460180  2019-12-18    group_1   1000
# 1598  2019-12-17  10457581         NaN        NaN      0
# 1599  2019-12-19  10473019  2019-12-20    group_4   7000
# 1600  2019-12-19  10469663  2019-12-20    group_4   7000
# 1601  2019-12-19  10472828  2019-12-20    group_1   1000
#
# [1602 rows x 10 columns]

# %%
bunp_user_reward = bunp_user.groupby(['reward'], as_index=False).agg({'created_at': 'count', 'uid': pd.Series.nunique})

bunp_user_reward
# Out:
#   reward  created_at  uid
# 0      0         883  552
# 1   1000         173  113
# 2   3000         204  106
# 3   5000         190  113
# 4   7000         152   91
