# %%
import pandas as pd
import numpy as np

# %%
path = '../csv/keyword_category_direct.csv'

df_category = pd.read_csv(path).drop('_num', axis=1)
df_category = df_category.rename(columns={'_count': 'count_click'})

df_category.tail()
# Out:
#                keyword  category     name  count_click
# 1891622  🖤아디다스 맨투맨 세트🖤       310     여성의류            1
# 1891623       😃👌 조립식주택       999       기타            2
# 1891624              😇       750  차량/오토바이            4
# 1891625         😈급처급처😇       100     커뮤니티            8
# 1891626              😘       400     패션잡화            1

# %%
path = '../csv/keyword_search.csv'

df_search = pd.read_csv(path)
df_search.tail()
# Out:
#                keyword  count_location  count_category  count_price_min  \
# 5035052  스톤아일랜드 코발트맨투맨               0               0                0
# 5035053         에르 키홀더               0               0                0
# 5035054          바이크완료               0               0                0
# 5035055         픽시크랭ㅋ.               0               0                0
# 5035056           베맥트화               0               0                0
#
#          count_price_max  count_used  count_bizseller  count_free_shipping  \
# 5035052                0           0                0                    0
# 5035053                0           0                0                    0
# 5035054                0           0                0                    0
# 5035055                0           0                0                    0
# 5035056                0           0                0                    0
#
#          count_exchg  count_none
# 5035052            0           1
# ...

# %%
df_search['count_option'] = df_search[['count_location', 'count_category', 'count_price_min', 'count_price_max', 'count_used', 'count_bizseller', 'count_free_shipping', 'count_exchg']].sum(axis=1)
df_search['total_search'] = df_search['count_none'] + df_search['count_option']

df_search.tail()
# Out:
#                keyword  count_location  count_category  count_price_min  \
# 5035052  스톤아일랜드 코발트맨투맨               0               0                0
# 5035053         에르 키홀더               0               0                0
# 5035054          바이크완료               0               0                0
# 5035055         픽시크랭ㅋ.               0               0                0
# 5035056           베맥트화               0               0                0
#
#          count_price_max  count_used  count_bizseller  count_free_shipping  \
# 5035052                0           0                0                    0
# 5035053                0           0                0                    0
# 5035054                0           0                0                    0
# 5035055                0           0                0                    0
# 5035056                0           0                0                    0
#
#          count_exchg  count_none  count_option  total_search
# ...

# %%
# Merge
df_search_category = pd.merge(df_search, df_category, how='left', on=['keyword'])

df_search_category = df_search_category[df_search_category['count_click'].notnull()]
# df_search_category['count_click'] = df_search_category['count_click'].astype(int)

df_search_category.tail()
# Out:
#          keyword  count_location  count_category  count_price_min  \
# 5035029  데일리먼데이.               0               0                0
# 5035034  정장소매스커트               0               0                0
# 5035036     3.1A               0               0                0
# 5035038    나그랑긴팔               0               0                0
# 5035046     다블퍼지               0               0                0
#
#          count_price_max  count_used  count_bizseller  count_free_shipping  \
# 5035029                0           0                0                    0
# 5035034                0           0                0                    0
# 5035036                0           0                0                    0
# 5035038                0           0                0                    0
# 5035046                0           0                0                    0
#
#          count_exchg  count_none  count_option  total_search  category  \
# ...

# %%
df_search_category_agg = df_search_category.groupby(['name']).agg('sum')

# df_search_category_agg = df_search_category.groupby(['name']).agg({'count_none': 'sum', 
#                                                                    'count_option': 'sum', 
#                                                                    'total_search': 'sum', 
#                                                                    'count_click': 'sum'})

save_path = '../csv/df_search_category_agg.csv'

df_search_category_agg.to_csv(save_path)

df_search_category_agg
# Out:
#              count_location  count_category  count_price_min  count_price_max  \
# name
# (구)패션의류                   3              14                0                0
# 구인구직                   7243             402                6                7
# 기타                   569231           29834             1917             3675
# 남성의류                7011846          573831           147286           254793
# 도서/티켓/취미/애완         2555279          216432            14330            23876
# 디지털/가전              7479898          473462           171834           270662
# 번개나눔                  36470            1366                3               40
# 뷰티/미용               1042084           58965             5384            16611
# 생활/문구/가구/식품         1620099           97504             6707            15834
# 스타굿즈                1424885           93582             5621             9317
# 스포츠/레저              2971112          142265            50726            95919
# ...

# %%
path = '../csv/test.csv'

df_test = pd.read_csv(path)

df_test.tail()
# Out:
#                                         search_option_json
# 3469561  {"location[]": "37.533273,127.070823,6km", "n"...
# 3469562  {"location[]": "37.405851,127.127090,10km", "n...
# 3469563  {"location[]": "34.931951,127.693275,6km", "n"...
# 3469564  {"location[]": "37.484220,127.023677,6km", "n"...
# 3469565  {"category_id": "310", "location[]": "37.50813...

# %%
print(type(df_test['search_option_json'][0]))
# Out:
# <class 'str'>

# %%
import json

def row_to_json(row):
    loads_row = json.loads(row)
    return json.dumps(loads_row)


df_test_json = df_test['search_option_json'].apply(row_to_json)
df_test_json.tail()
# Out:
# 3469561    {"location[]": "37.533273,127.070823,6km", "n"...
# 3469562    {"location[]": "37.405851,127.127090,10km", "n...
# 3469563    {"location[]": "34.931951,127.693275,6km", "n"...
# 3469564    {"location[]": "37.484220,127.023677,6km", "n"...
# 3469565    {"category_id": "310", "location[]": "37.50813...
# Name: search_option_json, dtype: object
